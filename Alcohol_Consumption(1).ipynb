# %% [markdown]
# Country: Unique Identifier
#
# Incomeperperson: Gross Domestic Product per capita in constant 2000 US$. The inflation but not the differences in the cost of living between countries has been taken into account.
#
# Alcconsumption: Alcohol consumption per adult (age 15+), litres Recorded and estimated average alcohol consumption, adult (15+) per capita consumption in litres pure alcohol
#
# Suicideper100TH: Suicide, age adjusted, per 100 000 Mortality due to self-inflicted injury, per 100 000 standard population, age adjusted
#
# Employrate: Total employees age 15+ (% of population) Percentage of total population, age above 15, that has been employed during the given year.
#
# Urbanrate: Urban population (% of total) Urban population refers to people living in urban areas.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import numpy as np
import warnings

# %%
data =  pd.read_csv('gapminder_alcohol.csv')

# %%
data.head(15)
# Out:
#                 country  alcconsumption  incomeperperson  suicideper100th  \
# 0           Afghanistan            0.03              NaN         6.684385
# 1               Albania            7.29      1914.996551         7.699330
# 2               Algeria            0.69      2231.993335         4.848770
# 3               Andorra           10.17     21943.339900         5.362179
# 4                Angola            5.57      1381.004268        14.554677
# 5   Antigua and Barbuda            8.17     11894.464070         2.161843
# 6             Argentina            9.35     10749.419240         7.765584
# 7               Armenia           13.66      1326.741757         3.741588
# 8                 Aruba             NaN              NaN              NaN
# 9             Australia           10.21     25249.986060         8.470030
# 10              Austria           12.40     26692.984110        13.094370
# 11           Azerbaijan           13.34      2344.896916         1.380965
# 12              Bahamas            8.65     19630.540550         3.374416
# 13              Bahrain            4.19     12505.212540         4.414990
# 14           Bangladesh            0.17       558.062877        14.538357
#
#     employrate  urbanrate
# 0    55.700001      24.04
# 1    51.400002      46.72
# 2    50.500000      65.22
# 3          NaN      88.92
# 4    75.699997      56.70
# 5          NaN      30.46
# 6    58.400002      92.00
# 7    40.099998      63.86
# 8          NaN      46.78
# 9    61.500000      88.74
# 10   57.099998      67.16
# 11   60.900002      51.92
# 12   66.599998      83.70
# 13   60.400002      88.52
# 14   68.099998      27.14

# %%
data.tail()
# Out:
#                 country  alcconsumption  incomeperperson  suicideper100th  \
# 208             Vietnam            3.91       722.807559        11.653322
# 209  West Bank and Gaza             NaN              NaN              NaN
# 210         Yemen, Rep.            0.20       610.357367         6.265789
# 211              Zambia            3.56       432.226337        12.019036
# 212            Zimbabwe            4.96       320.771890        13.905267
#
#      employrate  urbanrate
# 208   71.000000      27.84
# 209   32.000000      71.90
# 210   39.000000      30.64
# 211   61.000000      35.42
# 212   66.800003      37.34

# %%
data.shape
# Out:
# (213, 6)

# %%
data.describe().T
# Out:
#                  count         mean           std         min         25%  \
# alcconsumption   187.0     6.689412      4.899617    0.030000    2.625000
# incomeperperson  190.0  8740.966076  14262.809083  103.775857  748.245151
# suicideper100th  191.0     9.640839      6.300178    0.201449    4.988449
# employrate       178.0    58.635955     10.519454   32.000000   51.225000
# urbanrate        203.0    56.769360     23.844933   10.400000   36.830000
#
#                          50%          75%            max
# alcconsumption      5.920000     9.925000      23.010000
# incomeperperson  2553.496056  9379.891166  105147.437700
# suicideper100th     8.262893    12.328551      35.752872
# employrate         58.699999    64.975000      83.199997
# urbanrate          57.940000    74.210000     100.000000

# %% [markdown]
# alcconsumption vs incomeperperson

# %% [markdown]
# alcconsumption vs suicideper100th

# %% [markdown]
# employrate vs urbanrate

# %% [markdown]
# suicideper100th vs urbanrate

# %% [markdown]
# alcconsumption vs employrate

# %% [markdown]
# suicideper100th vs  incomeperperson

# %% [markdown]
# alcconsumption vs weather

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          213 non-null    object
#  1   alcconsumption   187 non-null    float64
#  2   incomeperperson  190 non-null    float64
#  3   suicideper100th  191 non-null    float64
#  4   employrate       178 non-null    float64
#  5   urbanrate        203 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 10.1+ KB

# %%
data2 = data

# %%
# Out:
#          country  alcconsumption  incomeperperson  suicideper100th  \
# 1        Albania            7.29      1914.996551         7.699330
# 2        Algeria            0.69      2231.993335         4.848770
# 4         Angola            5.57      1381.004268        14.554677
# 6      Argentina            9.35     10749.419240         7.765584
# 7        Armenia           13.66      1326.741757         3.741588
# ..           ...             ...              ...              ...
# 207    Venezuela            7.60      5528.363114         4.119620
# 208      Vietnam            3.91       722.807559        11.653322
# 210  Yemen, Rep.            0.20       610.357367         6.265789
# 211       Zambia            3.56       432.226337        12.019036
# 212     Zimbabwe            4.96       320.771890        13.905267
#
#      employrate  urbanrate
# 1     51.400002      46.72
# 2     50.500000      65.22
# 4     75.699997      56.70
# 6     58.400002      92.00
# 7     40.099998      63.86
# ..          ...        ...
# 207   59.900002      93.32
# 208   71.000000      27.84
# 210   39.000000      30.64
# 211   61.000000      35.42
# 212   66.800003      37.34
#
# [162 rows x 6 columns]

# %%
data2 = data.fillna(0)
data2[['alcconsumption']].astype(int)
# Out:
#      alcconsumption
# 0                 0
# 1                 7
# 2                 0
# 3                10
# 4                 5
# ..              ...
# 208               3
# 209               0
# 210               0
# 211               3
# 212               4
#
# [213 rows x 1 columns]

# %%
data.nunique()
# Out:
# country            213
# alcconsumption     180
# incomeperperson    190
# suicideper100th    191
# employrate         139
# urbanrate          194
# dtype: int64

# %%
data.isna().sum()
# Out:
# country             0
# alcconsumption     26
# incomeperperson    23
# suicideper100th    22
# employrate         35
# urbanrate          10
# dtype: int64

# %%
url = ’http://api.openweathermap.org/data/2.5/weather?
api_key = "4c1fa15b27f4e8aa87b0a2c01d2221e4"
country_name = data['country']
query_url = f'{url}{country_name}&appid={api_key}'
# Out:
# Object `weather` not found.

# %%
response = requests.get(url, params=params)

# %%
weatherdata =response.json()

# %%
weatherdata
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}

# %%
def histogram_boxplot(feature, figsize=(20, 10), bins=None):
   
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.distplot(
        feature, kde=F, ax=ax_hist2, bins=bins, color="orange"
    ) if bins else sns.distplot(
        feature, kde=False, ax=ax_hist2, color="tab:cyan"
    )  # For histogram
    ax_hist2.axvline(
        np.mean(feature), color="purple", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        np.median(feature), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
histogram_boxplot(data["alcconsumption"])
# Out:
# /Users/dan/.conda/envs/Nest/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dan/.conda/envs/Nest/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### The median on the Alcohol consumption in the dataset is 7.

# %%
histogram_boxplot(data["employrate"])
# Out:
# /Users/datinarwo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/datinarwo/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### The median on the Employement Rate in the dataset is 58%.

# %%
histogram_boxplot(data["incomeperperson"])
# Out:
# /Users/datinarwo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/datinarwo/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### The median on the Per Capital GDP in the dataset is 8740.96.

# %%
histogram_boxplot(data["suicideper100th"])
# Out:
# /Users/datinarwo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/datinarwo/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### The median on the Sucide Rate in the dataset is 9 per 100 000.

# %%
histogram_boxplot(data["urbanrate"])
# Out:
# /Users/datinarwo/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/datinarwo/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### The median on the urban rate is 58.

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot = True,fmt = ".2f",cbar = True,center=1)
plt.xticks(rotation= 45)
plt.yticks(rotation = 0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]),
#  [Text(0, 0.5, 'alcconsumption'),
#   Text(0, 1.5, 'incomeperperson'),
#   Text(0, 2.5, 'suicideper100th'),
#   Text(0, 3.5, 'employrate'),
#   Text(0, 4.5, 'urbanrate')])

# %% [markdown]
# ## Correlation
#
# - The highest correlation is between Urban Rate and Income per person with a rate of 0.49.
# - The correlation between Alcohol consumption and Suicides per 100 000 people is 0.35.
# - The correlation between Alcohol consumption and Income per person is .30.
# - The correlation between Alcohol consumption and Urban Rates .27.
# - The correlation between Income per person and Suicide Rates have a weak positive correlation .01.

# %%
try:
    sns.pairplot(data=data,hue="alcconsumption")
    plt.show()
except: variance()

# %%
try:
    cols = data[['alcconsumption','incomeperperson','suicideper100th','employrate','urbanrate']].columns.tolist()
    plt.figure(figsize=(12,7))

    for i, variable in enumerate(cols):
                     plt.subplot(3,2,i+1)
                     sns.boxplot(data["alcconsumption"],data[variable],palette="PuBu")
                     plt.tight_layout()
                     plt.title(variable)
    plt.show()
    
except: FutureWarning ()
# Out:
# /Users/dan/.conda/envs/Nest/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dan/.conda/envs/Nest/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dan/.conda/envs/Nest/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dan/.conda/envs/Nest/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/dan/.conda/envs/Nest/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data1 = data.sort_values(['alcconsumption'], ascending = False)

# %%
data3 = data1.iloc[:10]

# %%
data3.head(10)
# Out:
#          country  alcconsumption  incomeperperson  suicideper100th  \
# 126      Moldova           23.01       595.874534        15.538490
# 100  Korea, Rep.           19.15     16372.499780        22.404560
# 16       Belarus           18.85      2737.670379        26.874690
# 200      Ukraine           17.47      1036.830725        18.954570
# 59       Estonia           17.24      6238.537506        16.959240
# 49    Czech Rep.           16.47      7381.312751        12.367980
# 199       Uganda           16.40       377.421113        12.289122
# 110    Lithuania           16.30      5332.238591        33.341860
# 159       Russia           16.23      2923.144355        27.874160
# 158      Romania           16.15      2636.787800        10.059320
#
#      employrate  urbanrate
# 126   44.299999      41.76
# 100   58.900002      81.46
# 16    53.400002      73.46
# 200   54.400002      67.98
# 59    56.500000      69.46
# 49    56.000000      73.50
# 199   83.199997      12.98
# 110   53.099998      66.96
# 159   58.799999      72.84
# 158   49.500000      54.24

# %%
plt.bar(x = data3['country'], bottom = None, height= 5, width=0.8, align='edge')
plt.bar(x = data3['alcconsumption'])
plt.xticks(rotation= 90)
plt.yticks(rotation = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jj/qb8snw4x1vq9phpplw87ctxr0000gq/T/ipykernel_21029/3063565670.py in <module>
#       1 plt.bar(x = data3['country'], bottom = None, height= 5, width=0.8, align='edge')
# ----> 2 plt.bar(x = data3['alcconsumption'])
#       3 plt.xticks(rotation= 90)
#       4 plt.yticks(rotation = 0)
#
# TypeError: bar() missing 1 required positional argument: 'height'
